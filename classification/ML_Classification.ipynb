# %%
import pandas as pd
import numpy as np
import re
import joblib
from copy import deepcopy
from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('preprocess.csv')

data
# Out:
#                    name  category
# 0               아동영어보육과         0
# 1              아동영어보육학과         0
# 2              유아특수보육전공         1
# 3                특수보육계열         1
# 4                컴퓨터보육과         2
# ...                 ...       ...
# 27112    스마트이동체융합시스템공학과         3
# 27113  학과간협동과정항만물류시스템학과         3
# 27114        동북아물류시스템학과         3
# 27115           항만물류시스템         3
# 27116         교통에너지융합학과         3
#
# [27117 rows x 2 columns]

# %%
def category_str(data, classification=['인문', '사회', '교육', '공학', '자연', '의약', '예체능']):
    copy_data = deepcopy(data)
    for i in range(7):
        copy_data.loc[ copy_data['category']==i , 'category' ] = classification[i]
    return copy_data

# %%
def preprocess_name(text):
    result = ''
    
    # 빈칸제거
    result = text.strip()
    
    # 한글만 추출
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')  # 한글과 띄어쓰기를 제외한 모든 글자
    result = hangul.sub('', result)
    
    # 1차
    remove_words = ['학과', '전공', '학부', '대학', '계열', '단과대학없음', '프로그램', '과']
    result = result.strip().replace(' ', '').strip()
    
    if result in remove_words:
        return '0'
    else:
        return result

# %%
# data1 = category_str(data)

# data1

# %%
data2 = category_str(data, ['인문/사회', '인문/사회', '교육', '공학', '자연', '의약', '예체능'])

data2
# Out:
#                    name category
# 0               아동영어보육과    인문/사회
# 1              아동영어보육학과    인문/사회
# 2              유아특수보육전공    인문/사회
# 3                특수보육계열    인문/사회
# 4                컴퓨터보육과       교육
# ...                 ...      ...
# 27112    스마트이동체융합시스템공학과       공학
# 27113  학과간협동과정항만물류시스템학과       공학
# 27114        동북아물류시스템학과       공학
# 27115           항만물류시스템       공학
# 27116         교통에너지융합학과       공학
#
# [27117 rows x 2 columns]

# %%
x = data2['name'].to_list()

x
# Out:
# ['아동영어보육과',
#  '아동영어보육학과',
#  '유아특수보육전공',
#  '특수보육계열',
#  '컴퓨터보육과',
#  '가정보육과',
#  '보육과',
#  '보육상담전공',
#  '보육학과',
#  '사회복지보육과',
#  '생활보육과',
#  '아동미술보육전공',
#  '아동보육과',
#  '아동복지보육과',
#  '영유아보육과',
#  '유아교육과',
#  '유아교육전공',
#  '유아교육학과',
#  '유아미술음악전공',
#  '아동미술보육과',
#  '아동미술복지보육과',
#  '아동보육학습지도과',
#  '아동생활보육과',
#  '아동컴퓨터보육과',
#  '아동보육전공',
#  '방과후아동보육과',
#  '아동보육복지과',
#  '유아특수보육과',
#  '아동미술보육계열',
#  '아동보육계열',
#  '유아보육과',
#  '유아보육미술과',
#  '사회복지보육전공',
#  '특수보육과',
#  '아동문학보육과',
#  '아동미술복지보육전공',
#  '유아교육과년제',
#  '영유아보육복지과',
#  '아동복지미술보육과',
#  '유아교육과인문',
#  '미술보육과',
#  '아동보육복지학과',
#  '영유아보육전공',
#  '아동미디어미술보육과',
#  '아동표현미술보육과',
#  '유아교육학과년제',
#  '영재미술보육전공',
#  '보육복지과',
#  '아동보육학과',
#  '영유아보육학부',
#  '어린이영어보육과',
#  '아동보육복지전공',
#  '사회복지과아동보육복지전공',
#  '유아특수보육과년제',
#  '아동보육복지상담과',
#  '아동보육과인문사회',
#  '아동미술보육과년제',
#  '유아보육문화계열',
#  '영유아보육학과',
#  '아동복지보육과년제',
#  '유아보육계열',
#  '유아안전보육과',
#  '아동건강보육과',
#  '아동보육과년제',
#  '아동문화계열',
#  '아동상담보육과',
#  '유아특수보육학과',
#  '아동컴퓨터보육전공',
#  '아동조형미술보육과',
#  '아동미디어미술보육전공',
#  '아동표현미술보육전공',
#  '아동조형미술보육전공',
#  '유아특수치료교육',
#  '유아특수치료교육과',
#  '유아특수재활과',
#  '장애유아보육과',
#  '특수아동재활과',
#  '유아특수언어재활과',
#  '유아특수재활복지과',
#  '특수아동언어재활과',
#  '유아특수재활과년제',
#  '특수복지교육과',
#  '특수아동학과',
#  '장애유아보육학과',
#  '관광아동영어과',
#  '아동영어과',
#  '어린이영어지도과',
#  '아동영어지도과',
#  '아동영어지도전',
#  '영어과아동영어지도전공',
#  '유아영어지도과년제',
#  '사회교육과',
#  '컴퓨터교육학과',
#  '컴퓨터교육과',
#  '아동미술교육',
#  '아동예능지도과',
#  '아동예술교육과',
#  '어린이컴퓨터교육전공',
#  '아동미술교육과',
#  '아동영어지도전공',
#  '아동복지미술과',
#  '아동미술과년제인문',
#  '아동체육과인문',
#  '아동체육무용과',
#  '미술심리보육과',
#  '초등컴퓨터지도전공',
#  '아동무용지도자과',
#  '아동미술과',
#  '아동미술전공',
#  '아동조형미술과',
#  '아동미술지도전공',
#  '아동미술과년제',
#  '아동미술학과',
#  '아동미술지도과',
#  '아동미술지도학과',
#  '아동음악과',
#  '아동음악전공',
#  '아동음악지도전공',
#  '아동음악보육과',
#  '아동음악과년제',
#  '보건환경교육과',
#  '평생교육과',
#  '평생교육전공',
#  '환경교육과',
#  '아동평생교육학부',
#  '생활문화과',
#  '디자인계열',
#  '디자인학부',
#  '디자인학전공',
#  '디자인공학과',
#  '디자인과',
#  '예술디자인계열',
#  '디자인학과',
#  '디자인스쿨',
#  '광고보도영상과',
#  '광고창작과',
#  '광고홍보디자인전공',
#  '광고홍보영상과',
#  '홍보',
#  '홍보과',
#  '게임기획비즈니스과',
#  '뉴미디어과',
#  '뉴미디어학부',
#  '디지털미디어과',
#  '디지털미디어학과',
#  '매체예술',
#  '매체정보과',
#  '문예영상창작과',
#  '방송계열',
#  '방송극작',
#  '방송극작과',
#  '방송기술계열',
#  '방송기술과',
#  '방송매체과',
#  '방송미디어정보과',
#  '방송보도과',
#  '방송보도제작계열',
#  '방송설비과',
#  '방송연예생활음악과',
#  '방송연예제작과',
#  '방송영상계열',
#  '방송영상과',
#  '방송영상사진과',
#  '방송영상제작계열',
#  '방송영상학과군',
#  '방송영상학전공',
#  '방송이벤트설비전공',
#  '방송정보전자과',
#  '방송정보학과',
#  '방송제작과',
#  '방송제작기술과',
#  '신문방송과',
#  '영상문예과',
#  '영상문예창작과',
#  '웹미디어전공',
#  '인터넷미디어학부',
#  '인터넷방송전공',
#  '인터넷방송',
#  '인터넷방송계열',
#  '인터넷방송과',
#  '컴퓨터미디어계열',
#  '컴퓨터미디어학부',
#  '컴퓨터창작과',
#  '화상매체과',
#  '디지털방송영상과',
#  '미디어문예창작과',
#  '아동미디어과',
#  '인터넷신문방송과',
#  '매체예술과',
#  '미디어정보계열',
#  '디지털방송과',
#  '방송영상전공',
#  '디지털미디어전공',
#  '디지털방송미디어과',
#  '방송연예제작학부',
#  '광고디자인영상과',
#  '제작기술전공',
#  '방송아나운서과',
#  '미디어커뮤니케이션과',
#  '방송연예음악전공',
#  '방송기술전공',
#  '방송미디어정보전공',
#  '영상시나리오창작과',
#  '방송영상과년제',
#  '디지털방송과년제',
#  '정보미디어학부',
#  '방송인터넷기술전공',
#  '방송광고제작과',
#  '방송보도제작과',
#  '방송미디어학과',
#  '방송제작전공',
#  '신문방송전공',
#  '방송영상디지털계열',
#  '방송영상학부',
#  '아동표현창작과',
#  '방송영상스피치과',
#  '방송제작연예과',
#  '미디어문예창작전공',
#  '첨단방송영상계열',
#  '방송영상학과',
#  '스마트커뮤니케이션과',
#  '방송미디어과',
#  '첨단방송영상학과',
#  '방송보도제작학과',
#  '예술학부방송광고제작전공',
#  '방송미디어제작과',
#  '디지털방송미디어과공학',
#  '미디어출판학과',
#  '멀티미디어전공',
#  '컴퓨터멀티미디어전공',
#  '게임소프트웨어전공',
#  '스포츠게임과',
#  '웹멀티미디어전공',
#  '인터넷멀티미디어전공',
#  '디지털문화콘텐츠학과',
#  '게임과',
#  '게임모바일학과',
#  '영상방송과',
#  '디지털인쇄정보학과',
#  '디지털인쇄정보과',
#  '스마트폰미디어학과',
#  '영상방송학과',
#  '콘텐츠디자인과',
#  '디지털방송콘텐츠학과',
#  '게임공학과',
#  '게임멀티미디어전공',
#  '게임제작계열',
#  '게임학과',
#  '인터넷게임전공',
#  '컴퓨터게임개발과',
#  '컴퓨터게임과',
#  '컴퓨터게임전공',
#  '컴퓨터게임제작과',
#  '게임웨어',
#  '게임컨설팅과',
#  '모바일게임과',
#  '컴퓨터게임그래픽전공',
#  '게임웨어과',
#  '문화컨텐츠개발과',
#  '영상컨텐츠개발전공',
#  '인터넷게임과',
#  '컴퓨터게임정보과',
#  '게임창작과',
#  '게임전공',
#  '컴퓨터게임그래픽과',
#  '컴퓨터정보게임계열',
#  '사이버게임경영과',
#  '게임프로듀서과',
#  '게임엔터테인먼트과',
#  '게임제작과',
#  '스포츠',
#  '멀티게임영상과',
#  '스포츠과',
#  '게임학부',
#  '게임개발과',
#  '문화콘텐츠개발과',
#  '게임콘텐츠전공',
#  '컴퓨터게임제작전공',
#  '게임제작전공',
#  '스포츠전공',
#  '게임컨텐츠제작과',
#  '게임컨텐츠전공',
#  '컴퓨터게임그래픽학과',
#  '게임연출과',
#  '영상게임과',
#  '게임만화캐릭터과',
#  '게임평가운영과',
#  '관광멀티미디어게임과',
#  '게임영상그래픽과',
#  '게임콘텐츠과',
#  '컴퓨터게임과년',
#  '문화콘텐츠학과',
#  '게임컨텐츠과',
#  '멀티미디어게임과',
#  '영상게임콘텐츠과',
#  '비주얼게임컨텐츠과',
#  '방송음향영상학부',
#  '게임콘텐츠과년제',
#  '신산업창조학부전공',
#  '디지털정보미디어전공',
#  '인터넷미디어전공',
#  '정보미디어전공',
#  '모바일미디어전공',
#  '디지털영상콘텐츠과',
#  '시각영상콘텐츠과',
#  '영상컨텐츠개발과',
#  '컴퓨터정보계열게임전공',
#  '영상콘텐츠개발과',
#  '게임영상콘텐츠과',
#  '전자정보미디어전공',
#  '멀티미디어통신학과',
#  '디지털출판과',
#  '미디어홍보출판과',
#  '인쇄과',
#  '인쇄정보미디어과',
#  '전자출판과',
#  '전자편집디자인과',
#  '출판과',
#  '출판미디어',
#  '출판미디어과',
#  '출판인쇄과',
#  '출판정보미디어과',
#  '출판편집과',
#  '출판편집디자인전공',
#  '화상인쇄과',
#  '매체정보과인쇄미디어전공',
#  '매체정보과출판미디어전공',
#  '전자출판인쇄전공',
#  '출판미디어디자인전공',
#  '칼라리스트전공',
#  '미디어출판과',
#  '화상인쇄전공',
#  '컬러코디네이션전공',
#  '그래픽아츠과',
#  '그래픽아츠학과',
#  '디자인융합학과',
#  '프린팅융합디자인과',
#  '광고사인디자인전공',
#  '시각디자인계열',
#  '시각디자인과',
#  '시각디자인문화상품전공',
#  '시각디자인전공',
#  '시각디자인학과',
#  '시각멀티미디어디자인계열',
#  '시각멀티미디어디자인과',
#  '시각미디어디자인과',
#  '시각영상디자인계열',
#  '시각정보디자인영상디자인',
#  '시각정보디자인과',
#  '시각정보디자인전공',
#  '시각정보디자인학과',
#  '비주얼디자인계열',
#  '시각애니메이션디자인전공',
#  '캐릭터시각디자인전공',
#  '시각정보디자인계열',
#  '디지털시각디자인과',
#  '시각디자인애니메이션과',
#  '시각미디어전공',
#  '시각미디어디자인전공',
#  '산업디자인계열시각디자인전공',
#  '시각영상디자인과',
#  '광고시각디자인과',
#  '산업디자인학부시각디자인전공',
#  '디지털광고시각디자인전공',
#  '광고시각디자인전공',
#  '시각디자인과예체능계열',
#  '시각디자인과예체능',
#  '비주얼다이얼로그군',
#  '디자인학부산업디자인과시각디자인전공',
#  '산업디자인과시각디자인전공',
#  '예술학부시각리빙디자인전공',
#  '커뮤니케이션디자인',
#  '미디어아트앤디자인과',
#  '미디어아트앤디자인학과',
#  '시각디자인과자연과학계열',
#  '시각디자인과인문',
#  '시각디자인과년제',
#  '디자인학부시각디자인전공',
#  '시각디자인과시각정보디자인전공',
#  '시각디자인과그래픽디자인전공',
#  '시각디자인과디지털디자인전공',
#  '시각미디어디자인과년제',
#  '그래픽컨텐츠전공',
#  '그래픽콘텐츠전공',
#  '게임디자인학과',
#  '광고디자인과',
#  '광고디자인전공',
#  '광고디자인학과',
#  '광고멀티미디어디자인과',
#  '광고멀티미디어디자인전공',
#  '광고출판디자인계열',
#  '광고편집디자인전공',
#  '그래픽디자인',
#  '디자인멀티미디어전공',
#  '디지털광고디자인과',
#  '디지털광고디자인전공',
#  '디지털그래픽디자인',
#  '디지털디자인계열',
#  '디지털디자인학부',
#  '디지털미디어디자인전공',
#  '디지털미디어디자인학과',
#  '디지털미디어디자인학부',
#  '디지털전기디자인과',
#  '디지털컨텐츠디자인과',
#  '디지털컨텐트디자인전공',
#  '멀티광고디자인전공',
#  '멀티미디어디자인계열',
#  '멀티미디어디자인과',
#  '미디어디자인계열',
#  '미디어디자인학부',
#  '사진디자인전공',
#  '사진영상디자인학과',
#  '애니메이션디자인계열',
#  '애니메이션디자인과',
#  '영상디자인과',
#  '영상디자인전공',
#  '영상디자인학과',
#  '영상미디어디자인전공',
#  '영상사진디자인계열',
#  '출판디자인전공',
#  '캐릭터디자인전공',
#  '커뮤니케이션디자인과',
#  '컴퓨터광고디자인',
#  '컴퓨터그래픽디자인과',
#  '컴퓨터그래픽디자인전공',
#  '컴퓨터그래픽디자인학과',
#  '컴퓨터텍스타일디자인과',
#  '테크노디자인과',
#  '텍스타일디자인전공',
#  '그래픽스전공',
#  '광고영상디자인',
#  '광고영상디자인전공',
#  '디지털디자인전공',
#  '디지털영상디자인과',
#  '디지털제품디자인과',
#  '영상디자인계열',
#  '캐릭터광고디자인과',
#  '캐릭터애니메이션디자인과',
#  '커뮤니케이션디자인계열',
#  '컴퓨터그래픽디자인학부',
#  '컴퓨터영상디자인계열',
#  '출판디자인과',
#  '디지털디자인과',
#  '광고미디어과',
#  '게임디자인과',
#  '디지털그래픽디자인전공',
#  '그래픽스과',
#  '광고영상디자인과',
#  '방송영상디자인과',
#  '광고캐릭터디자인과',
#  '광고그래픽디자인과',
#  '캐릭터디자인과',
#  '디지털미디어디자인과',
#  '사인광고디자인과',
#  '컴퓨터광고디자인전공',
#  '게임디자인전공',
#  '캐릭터애니메이션디자인전공',
#  '산업디자인계열컴퓨터그래픽디자인전공',
#  '컴퓨터영상디자인과',
#  '광고편집과',
#  '사진디자인과',
#  '게임그래픽디자인전공',
#  '제작과',
#  '영화세트제작과',
#  '디자인전공',
#  '애니메이션디자인전공',
#  '그래픽과',
#  '영화세트과',
#  '산업디자인학부컴퓨터그래픽디자인전공',
#  '콘텐츠디자인전공',
#  '디지털디자인전공컴디',
#  '디지털디자인전공컴정',
#  '멀티디자인정보전공',
#  '디지털금형디자인전공',
#  '특수영상디자인전공',
#  '디지털컨텐츠디자인과년',
#  '영상디자인학부',
#  '디지털디자인학과',
#  '커뮤니케이션디자인학과',
#  '미디어디자인전공',
#  '광고영상디자인과예체능계열',
#  '광고편집과예체능',
#  '광고인테리어디자인과',
#  '디지털컨텐츠디자인계열',
#  '디지털콘텐츠디자인과',
#  '디지털미디어디자인과공학',
#  '미디어디자인과',
#  '광고미디어디자인과',
#  '디지털콘텐츠디자인과년',
#  '미디어디자인학과',
#  '게임미디어과',
#  '광고브랜드디자인과',
#  '방송영상디자인과년제',
#  '조형과',
#  '컴퓨터영상디자인전공',
#  '디자인영상콘텐츠학부',
#  '콘텐츠디자인계열',
#  '미디어디자인학과예체능',
#  '미디어디자인과예체능',
#  '광고홍보과예체능',
#  '멀티미디어디자인학과',
#  '시각미디어디자인학과',
#  '커뮤니케이션디자인학과년제',
#  '시각애니메이션콘텐츠과',
#  '콘텐츠과',
#  '디자인애니메이션학부',
#  '게임애니메이션',
#  '관광사진영상',
#  '관광사진예술과',
#  '광고사진과',
#  '디지털광고사진과',
#  '디지털만화과',
#  '디지털사진영상과',
#  '디지털사진영상전공',
#  '디지털애니메이션과',
#  '디지털애니메이션디자인학부',
#  '디지털영상애니메이션과',
#  '만화캐릭터전공',
#  '만화사진영상과',
#  '만화애니메이션전공',
#  '만화애니메이션학과',
#  '만화영상학과',
#  '만화영화과',
#  '만화예술과',
#  '만화예술전공',
#  '만화창작전공',
#  '모션그래픽과',
#  '미디어사진과',
#  '사진과',
#  '사진영상과',
#  '사진영상매체과',
#  '사진영상미디어과',
#  '사진영상학과',
#  '사진예술과',
#  '사진예술전공',
#  '애니메이션게임과',
#  '애니메이션과',
#  '애니메이션전공',
#  '애니메이션학과',
#  '영상애니메이션전공',
#  '웹애니메이션전공',
#  '캐릭터애니메이션과',
#  '캐릭터애니메이션전공',
#  '컴퓨터문화산업계열',
#  '컴퓨터애니메이션',
#  '컴퓨터애니메이션과',
#  '컴퓨터애니메이션전공',
#  '디지털애니메이션디자인과',
#  '만화애니메이션디자인과',
#  '애니메이션계열',
#  '애니메이션학부',
#  '영상애니메이션과',
#  '영화방송애니메이션과',
#  '게임애니메이션과',
#  '게임애니메이션전공',
#  '디지털사진애니메이션과',
#  '방송사진영상과',
#  '인터넷만화과',
#  '만화창작과',
#  '사진전공',
#  '게임애니메이션계열',
#  '캐릭터만화애니과',
#  '만화애니메이션과',
#  '만화전공',
#  '만화일러스트레이션과',
#  '미술만화과',
#  '만화영상애니메이션과',
#  '카툰애니메이션과',
#  '에니메이션영상전공',
#  '광고에니메이션전공',
#  '멀티미디어영상전공',
#  '만화영상애니메이션학과',
#  '사진영상미디어과년제',
#  '디지털만화영상과',
#  '실용사진전공',
#  '카툰애니메이션학과',
#  '만화애니게임학과',
#  '사진영상미디어학과',
#  '만화콘텐츠과',
#  '드론사진영상과',
#  '웹툰창작과',
#  '만화애니메이션콘텐츠',
#  '웹툰만화콘텐츠전공',
#  '웹툰만화창작학과',
#  '만화애니메이션학부',
#  '만화콘텐츠학과',
#  '공간예술',
#  '디지털아트과',
#  '디지털영상계열',
#  '디지털영상미디어과',
#  '디지털영상학과',
#  '산업영상과',
#  '산업예술계열',
#  '산업응용계열',
#  '스포츠예술',
#  '시간예술',
#  '영상광고창작기획과',
#  '영상광학전공',
#  '영상그래픽과',
#  '영상멀티미디어',
#  '영상문화과',
#  '영상미디어과',
#  '영상미디어전공',
#  '영상미디어제작전공',
#  '영상미디어학과',
#  '영상산업과',
#  '영상예술과',
#  '영상음악과',
#  '영상정보과',
#  '영상정보시스템계열',
#  '영상정보처리과',
#  '영상제작계열',
#  '영상제작과',
#  '영상촬영조명과',
#  '영상편집과',
#  '영상편집기술과',
#  '영화영상과',
#  '이벤트예술과',
#  '인터넷영상과',
#  '일러스트레이션카툰전공',
#  '일러스트레이션과',
#  '일러스트레이션전공',
#  '전자그래픽과',
#  '전통공연예술과',
#  '창작기획',
#  '첨단영상미디어과',
#  '촬영조명과',
#  '커뮤니케이션아트계열',
#  '컴퓨터그래픽과',
#  '컴퓨터그래픽스',
#  '컴퓨터그래픽스전공',
#  '컴퓨터그래픽학과',
#  '공연기획과',
#  '공연영상제작학부',
#  '디지털영화제작전공',
#  '무대공연전공',
#  '아트조명과',
#  '엔터테인먼트과',
#  '연예매니지먼트과',
#  '영상멀티미디어과',
#  '영상정보전공',
#  '영상컨텐츠과',
#  '인터넷영상미디어과',
#  '촬영조명전공',
#  '편집제작기술전공',
#  '시간예술과',
#  '방송영상아트과',
#  '미디어영상전자과',
#  '컴퓨터그래픽스과',
#  '실용예술학부',
#  '광고영상과',
#  '디지털아트학부',
#  '문화예술학부',
#  '미디어영상시스템과',
#  '방송영상미디어과',
#  '영상그래픽디자인과',
#  '영화영상디자인계열',
#  '편집제작과',
#  '엔터테인먼트비즈니스전공',
#  '마술전공',
#  '영상예술학부',
#  '영상제작전공',
#  '영상연예과',
#  '디지털영상과',
#  '영화영상그래픽과',
#  '엔터테인먼트계열',
#  '엔터테인먼트비즈니스과',
#  '영상콘텐츠과',
#  '영상음악계열',
#  '영상디스플레이과',
#  '실용미디어창작과',
#  '멀티영상과',
#  '방송엔터테인먼트과',
#  '방송영상제작과',
#  '컴퓨터그래픽전공',
#  '방송영화비주얼코디과',
#  '퓨전공연예술과',
#  '방송영화디자인과',
#  '방송영상제작전공',
#  '쇼이벤트전공',
#  '아동문화과예체능',
#  '매직엔터테인먼트과',
#  '방송학부',
#  '방송엔터테인먼트계열',
#  '방송영화과',
#  '매직엔터테인먼트전공',
#  '연예메니지먼트전공',
#  '연예매니지먼트전공',
#  '영상공연',
#  '디지털영상제작전공',
#  '이벤트무대예술전공',
#  '기독교영상예술전공',
#  '방송영화영상전공',
#  '연예매니지먼트공연이벤트전공',
#  '미디어창작학부',
#  '디지털영상미디어전공',
#  '영상공연학부',
#  '방송영화제작전공',
#  '디지털영상편집전공',
#  '무대예술전공',
#  '영상방송정보전공',
#  '방송영상연예예술과',
#  '영상콘텐츠학과',
#  '방송영화그래픽과',
#  '디지털영상전공',
#  '영상편집제작과',
#  '예술품관리과',
#  '방송음향영상전공',
#  '방송스타일리스트과',
#  '영상컴퓨터과',
#  '연예매니지먼트공연이벤트과',
#  '영화방송연예제작과',
#  '방송연예영상예술과',
#  '영상정보계열',
#  '엔터테인먼트과인문사회계열',
#  '방송음향영상과',
#  '방송영화제작계열',
#  '아트앤플레이군',
#  '영상문화콘텐츠과',
#  '미디어영상계열',
#  '방송영화연예제작과',
#  '영상방송정보과',
#  '디자인학부디지털영상미디어과',
#  '멀티미디어영상과',
#  '입체영상미디어과',
#  '방송영상광고과',
#  '이벤트프래너과',
#  '영상그래픽전공',
#  '그래픽영상전공',
#  '입체영상애니메이션전공',
#  '만화영상그래픽전공',
#  '방송영화제작과',
#  '영상컨텐츠전공',
#  '방송영화제작학과',
#  '언론방송창작과',
#  '공연콘텐츠전공',
#  '영상콘텐츠전공',
#  '융합예술과',
#  '방송콘텐츠과',
#  '미디어부사관학과',
#  '입체영상과',
#  '방송제작연예과영상제작전공',
#  '미디어부사관과',
#  '방송보도제작계열방송저널리즘전공',
#  '방송보도제작계열아나운싱전공',
#  '방송예술융합계열',
#  '방송예술융합계열방송시스템전공',
#  '방송예술융합계열방송제작기술전공',
#  '방송예술융합계열방송통신기술전공',
#  '방송예술융합학과',
#  '영상콘텐츠과예체능',
#  '영상콘텐츠학과예체능',
#  '광고창작전공',
#  '디지털아트전공',
#  '시각디자인과산업그래픽전공',
#  '시각디자인과디지털미디어전공',
#  '특수영상제작과',
#  '영상부사관과',
#  '융합예술과년제',
#  '문화융복합학부',
#  '게임애니메이션학과',
#  '광고영상디자인학과',
#  '마술컨텐츠과',
#  '방송기술계열방송시스템전공',
#  '방송기술계열방송음향기술전공',
#  '방송기술계열방송제작기술전공',
#  '방송기술계열방송통신기술전공',
#  '방송기술계열예체능',
#  '방송기술학과',
#  '방송문화콘텐츠과',
#  '방송영화제작예술과',
#  '방송영화제작예술학과',
#  '스마트미디어전공',
#  '영상정보부사관과',
#  '영화영상학과',
#  '방송영상미디어학과',
#  '영상드론콘텐츠과',
#  '방송영상콘텐츠과',
#  '방송미디어과년제',
#  '미디어영상스피치과',
#  '디지털영상비주얼디자인학부',
#  '방송영상무대예술전공',
#  '영상학부',
#  '방송연예영상계열',
#  '영상무대디자인과',
#  '신산업창조학부',
#  '방송영상미디어계열',
#  '융합예술학과',
#  '방송음향영상학과',
#  '방송영상제작전공년제',
#  '영상촬영조명학과',
#  '드론영상정보과',
#  '영화과',
#  '영화전공',
#  '영화제작과',
#  '애니메이션영화과',
#  '영화멀티미디어과',
#  '영화방송제작과',
#  '영화방송과',
#  '방송영상영화과',
#  '방송영상연기학부',
#  '영화방송미디어학과',
#  '영화방송예술과',
#  '영화방송예술학과',
#  '공연영상과',
#  '영화방송공연예술학과',
#  '영상음악학과',
#  '음향공학과',
#  '음향전자기기학과',
#  '음향제작계열',
#  '음향제작과',
#  '음향학과',
#  '음향제작전공',
#  '음향과',
#  '음향미디어전공',
#  '음향제작학과',
#  '방송예술융합계열방송음향기술전공',
#  '패션디자인학과',
#  '애완동물뷰티패션디자인전공',
#  '슈즈패션산업과',
#  '패션디자인비즈니스과',
#  '섬유패션디자인계열',
#  '섬유패션디자인학부',
#  '의상디자인계열',
#  '의상디자인과',
#  '의상디자인전공',
#  '전통복식디자인과',
#  '토탈패션계열',
#  '토탈패션과',
#  '패션계열',
#  '패션디자인계열',
#  '패션디자인과',
#  '패션디자인산업과',
#  '패션디자인코디과',
#  '패션디자인전공',
#  '패션산업디자인계열',
#  '패션산업디자인과',
#  '패션섬유디자인계열',
#  '패션코스튬디자인',
#  '한국의상디자인전공',
#  '섬유패션디자인과',
#  '토탈패션디자인과',
#  '패션뷰티디자인학부',
#  '니트패션디자인과',
#  '토탈패션비즈니스과',
#  '패션디자인이벤트과',
#  '패션뷰티디자인과',
#  '섬유패션디자인전공',
#  '패션뷰티코디네이션과',
#  '패션섬유코디네이션과',
#  '패션스타일디자인과',
#  '패션학부',
#  '컴퓨터패션디자인전공',
#  '패션메이킹과',
#  '의상디자인학과',
#  '패션뷰티계열',
#  '패션섬유코디네이션전공',
#  '패션액세서리디자인전공',
#  '패션웨딩스타일리스트과',
#  '섬유의상코디과',
#  '패션코디디자인과',
#  '패션디자인과년제',
#  '패션문화디자인과',
#  '디자인학부패션코디디자인과',
#  '니트패션디자인과년제',
#  '슈즈디자인전공',
#  '리빙패션디자인과',
#  '예술학부뷰티패션디자인전공',
#  '섬유패션디자인학과',
#  '패션슈즈디자인과',
#  '패션학부패션디자인전공',
#  '패션테크니컬디자인전공',
#  '패션주얼리디자인과',
#  '니트패션디자인학과',
#  '한국의상과',
#  '패션디자인비즈니스전공',
#  '디자인학부패션디자인전공',
#  '패션문화디자인과자연과학계열',
#  '패션브랜드매니저과',
#  '패션디자인과예체능',
#  '패션스타일리스트학과',
#  '패션생활디자인과',
#  '패션디자인마케팅과',
#  '패션학과',
#  '패션메이커스스타일리스트전공',
#  '패션메이커스비즈니스학과',
#  '패션메이커스전공',
#  '섬유디자인전공',
#  '패션악세사리디자인과',
#  '패션주얼리과',
#  '니트디자인과',
#  '패션리빙디자인과',
#  '패션스쿨',
#  '방송엔터테인먼트코디과',
#  '뷰티아트디자인과',
#  '방송코디네이션디자인과',
#  '패션뷰티디자인학부패션스페셜리스트전공',
#  '패션뷰티디자인학부패션스타일리스트전공',
#  '뷰티아트디자인학과',
#  '패션뷰티과',
#  '전시디자인학과',
#  '실내공간인테리어과',
#  '실내인테리어과',
#  '건축인테리어디자인학과',
#  '실내인테리어리모델링과',
#  '실내리모델링인테리어과',
#  '실내인테리어디자인과',
#  '인테리어디스플레이과',
#  '실내환경디자인학과',
#  '시각귀금속디자인과',
#  '산업융합디자인과',
#  '디지털산업디자인계열',
#  '디지털산업디자인과',
#  '문화산업디자인전공',
#  '산업공예디자인과',
#  '산업공예디자인전공',
#  '산업도자기디자인전공',
#  '산업도자디자인전공',
#  '산업디자인계열',
#  '산업디자인공학과',
#  '산업디자인과',
#  '산업디자인전공',
#  '산업디자인정보계열',
#  '산업디자인학과',
#  '산업디자인학부',
#  '산업정보디자인계열',
#  '산업정보디자인과',
#  '산업정보디자인학부',
#  '산업제품디자인과',
#  '상업디자인과',
#  '상업디자인학전공',
#  '정보산업디자인과',
#  '캐릭터산업디자인과',
#  '캐릭터산업디자인전공',
#  '컴퓨터산업디자인과',
#  '멀티산업디자인계열',
#  '산업도자디자인과',
#  '산업디자인',
#  '산업제품디자인전공',
#  '멀티산업디자인과',
#  '문화산업디자인과',
#  '도예산업디자인과',
#  '하이테크디자인과',
#  '문화정보디자인전공',
#  '산업디자인계열년',
#  '코디네이션광고디자인과',
#  '색채산업디자인과',
#  '산업디자인과예체능',
#  '디지털산업디자인전공',
#  '색채산업디자인학과',
#  '복지산업디자인과',
#  '산업디자인계열년제',
#  '색채디자인과',
#  '색채디자인학과',
#  '디지털산업디자인학과',
#  '산업디자인과자연과학계열',
#  '산업디자인학과자연과학계열',
#  '산업디자인학과예체능',
#  '테크노산업디자인과산업디자인전공',
#  '산업디자인과년제',
#  '패션워크디자인과',
#  '테크노산업디자인학과산업디자인전공',
#  '호텔광고디자인과',
#  '인테리어패션디자인과',
#  '가구디자인과',
#  '가구디자인전공',
#  '가구실내디자인',
#  '건축공간디자인계열',
#  '건축디자인과',
#  '건축디자인전공',
#  '건축실내디자인학부',
#  '건축실내디자인과',
#  '건축토털디자인과',
#  '건축환경디자인계열',
#  '건축환경디자인과',
#  '공간디자인계열',
#  '공간디자인학부',
#  '공간조형디자인전공',
#  '공업디자인과',
#  '공예디자인과',
#  '공예디자인전공',
#  '관광디자인계열',
#  '그래픽디자인계열',
#  '그래픽디자인과',
#  '그래픽디자인전공',
#  '그래픽산업디자인',
#  '금속공예디자인과',
#  '금속공예디자인전공',
#  '금속금형디자인과',
#  '금속제품디자인과',
#  '기계디자인과',
#  '뉴테크디자인계열',
#  '도자디자인과',
#  '도자디자인전공',
#  '디자인멀티미디어',
#  '디자인미술영상학부',
#  '디자인영상계열',
#  '멀티뷰티디자인과',
#  '문화상품디자인',
#  '미디어아트디자인과',
#  ...]

# %%
model = SentenceTransformer('jhgan/ko-sroberta-multitask')
embeddings = model.encode(x)

embeddings.shape
# Out:
# (27117, 768)

# %%
scaler = StandardScaler()
scale_embeddings = scaler.fit_transform(embeddings)

scale_embeddings.shape
# Out:
# (27117, 768)

# %%
def pca_decide(n, data=scale_embeddings):
    pca = PCA(n_components=n)  # 주성분을 몇개로 할지 결정
    test = pca.fit_transform(data)
    df = pd.DataFrame(data=test, columns=[f"pca{num+1}" for num in range(n)])
    
    var = pca.explained_variance_
    ratio = pca.explained_variance_ratio_

    results = pd.DataFrame({'설명가능한 분산 비율(고윳값)':var, '기여율':ratio},
                         index = np.array([f"pca{num+1}" for num in range(n)]))
    results['누적기여율'] = results['기여율'].cumsum()
    
    if results['누적기여율'][-1] >= 0.8:
        return results
    

def find_dimension():
    for n in range(3, 100):
        result = pca_decide(n)
        try:
            if result['설명가능한 분산 비율(고윳값)'][-1] >= 0.7:
                print(result)
                return n
        except:
            pass

# %%
dimension = find_dimension()

print(f"{dimension} 차원")
# Out:
#        설명가능한 분산 비율(고윳값)       기여율     누적기여율
# pca1          42.979969  0.055962  0.055962
# pca2          36.224873  0.047166  0.103128
# pca3          33.651028  0.043815  0.146943
# pca4          26.627037  0.034669  0.181612
# pca5          23.817713  0.031012  0.212624
# ...                 ...       ...       ...
# pca74          2.162385  0.002816  0.791082
# pca75          2.107677  0.002744  0.793826
# pca76          2.024973  0.002637  0.796463
# pca77          2.011824  0.002619  0.799082
# pca78          1.967391  0.002562  0.801644
#
# [78 rows x 3 columns]
# 78 차원

# %%
pca = PCA(n_components=dimension) # 주성분을 몇개로 할지 결정
test = pca.fit_transform(scale_embeddings)
X = pd.DataFrame(data=test, columns=[f"pca{num+1}" for num in range(dimension)])

X
# Out:
#             pca1      pca2      pca3       pca4       pca5      pca6  \
# 0     -10.551537 -0.762775 -0.160745   7.201861   2.393254  2.654530
# 1      -8.657743 -1.747990  1.240400   6.341300  -2.442683  3.103930
# 2      -4.485785 -2.786307 -0.961320   9.138314  -3.725596  3.920368
# 3      -5.706595 -1.581038 -3.901399   8.444745   0.884113  1.012693
# 4      -2.114228 -1.476661  5.808383  10.699887   5.400667  4.259630
# ...          ...       ...       ...        ...        ...       ...
# 27112   9.792550 -3.351503  6.869967   0.304764   3.303104 -0.960837
# 27113   4.715854 -4.266459  0.707244  -6.709499   1.166898 -0.377644
# 27114  -0.030081 -5.204044  1.515163 -13.278986   3.867821 -2.989610
# 27115  -0.031049 -2.405849  0.565100  -9.701809  11.256230 -3.154013
# 27116  11.122231 -2.016954  0.887091  -5.122044   0.573601 -1.257695
#
#            pca7      pca8      pca9     pca10  ...     pca69     pca70  \
# 0      6.030195  1.441372  8.255816 -1.908117  ...  1.049923 -1.320524
# 1      3.576960 -2.316741  4.974585 -1.694937  ...  0.589120 -0.989491
# 2     -3.522317  1.608313  6.323623 -1.267553  ...  2.292867 -0.988961
# 3     -1.870608  3.692781  4.374101 -1.916776  ... -0.366730  2.394121
# 4      4.669299  2.216892  6.183907 -2.881601  ...  0.144234 -1.237799
# ...         ...       ...       ...       ...  ...       ...       ...
# 27112 -2.588651  4.521898  1.489481  7.109532  ...  1.725079  1.271450
# 27113 -6.187341  1.759470  6.464660 -0.776340  ... -0.275945 -0.230087
# 27114 -0.761097  1.778814  4.786293  0.246323  ...  0.558633 -0.716457
# 27115  2.138202  5.574687  5.877253  0.915709  ... -0.376467 -2.232781
# 27116  4.576232  2.520268  4.858935  8.590472  ...  2.382413 -0.497356
#
#           pca71     pca72     pca73     pca74     pca75     pca76     pca77  \
# 0     -1.524433  0.357707  0.437007 -0.565915  0.185978  0.971343 -1.348406
# 1     -2.198092  0.590839  0.820283  0.680415  0.706436  0.680426 -0.941230
# 2      2.904807  3.130840  2.332872 -0.386782 -0.625766  0.476261  1.572197
# 3      5.103293 -0.536843  2.417065 -0.966940  0.683079  0.486850  2.501941
# 4      0.284154  1.829115  0.960550 -2.840800 -0.898652  1.493218  0.338334
# ...         ...       ...       ...       ...       ...       ...       ...
# 27112 -0.567695 -0.111219  0.883647  0.796527  0.354574  1.098843 -0.328075
# 27113  1.987767 -0.122264  0.829649  1.910535  0.391578  0.989922 -0.975805
# 27114  1.920569  1.483391  2.957964  1.674624 -0.832306 -1.511633 -0.321255
# 27115  1.813420  0.661504  2.585765 -0.084849  0.974733 -2.725560 -1.177815
# 27116 -0.396887  0.531509  0.487064 -1.364525  0.373614 -1.509984 -0.017851
#
#           pca78
# 0      1.382653
# 1      1.105813
# 2     -1.370518
# 3     -1.943419
# 4     -0.365020
# ...         ...
# 27112  0.063152
# 27113 -0.248757
# 27114 -0.687260
# 27115  1.648617
# 27116 -0.655089
#
# [27117 rows x 78 columns]

# %%
y = data2['category']

y
# Out:
# 0        인문/사회
# 1        인문/사회
# 2        인문/사회
# 3        인문/사회
# 4           교육
#          ...
# 27112       공학
# 27113       공학
# 27114       공학
# 27115       공학
# 27116       공학
# Name: category, Length: 27117, dtype: object

# %%
rfm = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_leaf=3)

rfm.fit(X.values, y.values)

joblib.dump(model, './rf_model.pkl')

# %%
seogang_class = [
    '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', 
    '인문/사회', '인문/사회', '인문/사회', '인문/사회', '인문/사회', 
    '예체능', '예체능',  '예체능', '예체능', '예체능', '예체능', 
    '자연', '자연', '자연', '자연', 
    '공학', '공학', '공학', '공학', '공학', '공학'
]

seogang_major = [
    '국어국문학', '사학', '철학', '종교학', '영문학부', '유럽문화', '독일문화', '프랑스문화', '중국문화', '일본문화', 
    '사회학', '정치외교학', '심리학', '경제학', '경영학', 
    '국제한국학', '아트&테크놀로지', '신문방송학', '미디어&엔터테인먼트', '글로벌 한국학', '커뮤니케이션학', 
    '수학', '물리학', '화학', '생명과학', 
    '전자공학', '화공생명공학', '컴퓨터공학', '기계공학', '인공지능학', '시스템반도체공학'
]

# %%
majors = []
for word in seogang_major:
    majors.append(preprocess_name(word))
    
majors
# Out:
# ['국어국문학',
#  '사학',
#  '철학',
#  '종교학',
#  '영문학부',
#  '유럽문화',
#  '독일문화',
#  '프랑스문화',
#  '중국문화',
#  '일본문화',
#  '사회학',
#  '정치외교학',
#  '심리학',
#  '경제학',
#  '경영학',
#  '국제한국학',
#  '아트테크놀로지',
#  '신문방송학',
#  '미디어엔터테인먼트',
#  '글로벌한국학',
#  '커뮤니케이션학',
#  '수학',
#  '물리학',
#  '화학',
#  '생명과학',
#  '전자공학',
#  '화공생명공학',
#  '컴퓨터공학',
#  '기계공학',
#  '인공지능학',
#  '시스템반도체공학']

# %%
emb = model.encode(majors)

scale_emb = scaler.transform(emb)

scale_emb.shape
# Out:
# (31, 768)

# %%
tes = pca.transform(scale_emb)

tes.shape
# Out:
# (31, 78)

# %%
loaded_model = joblib.load('./rf_model.pkl')

score = loaded_model.score(tes, seogang_class)
pred = loaded_model.predict(tes)

print(pred)
print('정확도: {score:.3f}'.format(score=score))
# Out:
# ['인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회'
#  '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '인문/사회' '예체능' '인문/사회'
#  '인문/사회' '인문/사회' '인문/사회' '자연' '자연' '인문/사회' '자연' '공학' '공학' '공학' '공학' '공학'
#  '공학']
# 정확도: 0.806
